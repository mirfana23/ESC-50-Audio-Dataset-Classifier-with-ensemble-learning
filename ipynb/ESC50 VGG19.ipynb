# %% [markdown]
# ##Mount Google Drive

# %%
import os
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ##Set up root

# %%
# Specify the directory path
root = '/gdrive/MyDrive/Irfan/ESC-50-master'
# !ls '/gdrive/MyDrive/Irfan/ESC-50-master'
# Out:
#  audio		    esc50.gif   melspectrograms   pytest.ini   requirements.txt
# 'audio augmented'   LICENSE     meta		  README.md    tests

# %% [markdown]
# ##Import Libraries

# %%
from keras.applications.vgg19 import VGG19, preprocess_input #CHANGE THIS TO DIFFERENT MODEL
from keras.preprocessing import image
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Input
from keras.applications.vgg16 import preprocess_input
from matplotlib import pyplot as plt
import numpy as np
import json as js

# %% [markdown]
# ##Set Parameter Values

# %%
batch_size = 32
epochs = 120

# dimensions of our images.
img_width, img_height = 224, 224

input_tensor = Input(shape=(224,224,3))

nb_training_samples = 1600
nb_validation_samples = 400# Set parameter values

# %% [markdown]
# ##Data Loader

# %%
# training generator configuration
training_data_dir = root + '/audio augmented/training'

training_datagen = image.ImageDataGenerator(
    rescale=1./255)

training_generator = training_datagen.flow_from_directory(
    training_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)

# validation generator configuration
validation_data_dir = root + '/audio augmented/testing/'

validation_datagen = image.ImageDataGenerator(
    rescale=1./255)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 4800 images belonging to 50 classes.
# Found 1200 images belonging to 50 classes.

# %% [markdown]
# ##Base Model

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_tensor=input_tensor) #CHANGE THIS TO THE NAME OF THE MODEL
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Top Model

# %%
# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(50, activation='softmax')) #CHANGE HERE FOR THE AMOUNT OF CLASS
top_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                12850
# =================================================================
# Total params: 6,435,634
# Trainable params: 6,435,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Base + Top

# %%
model = Model(inputs=base_model.input, outputs=top_model(base_model.output))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# sequential (Sequential)      (None, 50)                6435634
# =================================================================
# Total params: 26,460,018
# Trainable params: 26,460,018
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Training configuration

# %%
from keras import metrics, optimizers

num_layers_to_freeze = 15

def top_5_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=5)

for layer in model.layers[:num_layers_to_freeze]:
    layer.trainable = False

# optimizer=optimizers.SGD(lr=1e-4, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), 
                      loss='categorical_crossentropy', 
                      metrics=['accuracy', top_5_accuracy])

# serialize model to JSON
model_json = model.to_json()
model_filename = "vgg16_model_{}_frozen_layers.json".format(num_layers_to_freeze)
with open(model_filename, "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ##Training Pipeline

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard
from time import time

tensorboard = TensorBoard(log_dir="logs/layers_frozen_{}".format(num_layers_to_freeze))

# checkpoint
filepath= "/gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5" #CHANGE THIS TOO
best_model_checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [best_model_checkpoint, tensorboard]


history = model.fit(
    training_generator,
    steps_per_epoch=nb_training_samples/batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples/batch_size,
    callbacks=callbacks_list)

# evaluate the model
train_acc = history.history['accuracy']
test_acc = history.history['val_accuracy']
print('%s train accuracy: %.3f, %s test accuracy: %.3f' % (model, train_acc[0], model, test_acc[0]))

#plotting accuracy
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.title(str(model) + 'accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

#plotting loss
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.title(str(model) + 'loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

filename = '/gdrive/MyDrive/Irfan/models/h5/VGG19.h5' #CHANGE THIS
model.save(filename)
print('>Saved %s' % filename)
# Out:
# Epoch 1/120
# 50/50 [==============================] - 754s 15s/step - loss: 4.1764 - accuracy: 0.0227 - top_5_accuracy: 0.1103 - val_loss: 3.8660 - val_accuracy: 0.0312 - val_top_5_accuracy: 0.1755
#
# Epoch 00001: val_accuracy improved from -inf to 0.03125, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 2/120
# 50/50 [==============================] - 457s 9s/step - loss: 3.8891 - accuracy: 0.0345 - top_5_accuracy: 0.1402 - val_loss: 3.8244 - val_accuracy: 0.0793 - val_top_5_accuracy: 0.2332
#
# Epoch 00002: val_accuracy improved from 0.03125 to 0.07933, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 3/120
# 50/50 [==============================] - 350s 7s/step - loss: 3.8368 - accuracy: 0.0374 - top_5_accuracy: 0.1653 - val_loss: 3.7954 - val_accuracy: 0.0625 - val_top_5_accuracy: 0.2524
#
# Epoch 00003: val_accuracy did not improve from 0.07933
# Epoch 4/120
# 50/50 [==============================] - 194s 4s/step - loss: 3.8217 - accuracy: 0.0541 - top_5_accuracy: 0.1872 - val_loss: 3.7423 - val_accuracy: 0.0409 - val_top_5_accuracy: 0.2548
#
# Epoch 00004: val_accuracy did not improve from 0.07933
# Epoch 5/120
# 50/50 [==============================] - 136s 3s/step - loss: 3.7538 - accuracy: 0.0532 - top_5_accuracy: 0.2416 - val_loss: 3.6439 - val_accuracy: 0.0962 - val_top_5_accuracy: 0.3534
#
# Epoch 00005: val_accuracy improved from 0.07933 to 0.09615, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 6/120
# 50/50 [==============================] - 86s 2s/step - loss: 3.6642 - accuracy: 0.0795 - top_5_accuracy: 0.2708 - val_loss: 3.5530 - val_accuracy: 0.1514 - val_top_5_accuracy: 0.4303
#
# Epoch 00006: val_accuracy improved from 0.09615 to 0.15144, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 7/120
# 50/50 [==============================] - 62s 1s/step - loss: 3.5511 - accuracy: 0.0878 - top_5_accuracy: 0.3386 - val_loss: 3.4660 - val_accuracy: 0.1851 - val_top_5_accuracy: 0.4832
#
# Epoch 00007: val_accuracy improved from 0.15144 to 0.18510, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 8/120
# 50/50 [==============================] - 46s 894ms/step - loss: 3.4984 - accuracy: 0.0941 - top_5_accuracy: 0.3604 - val_loss: 3.3178 - val_accuracy: 0.2572 - val_top_5_accuracy: 0.5337
#
# Epoch 00008: val_accuracy improved from 0.18510 to 0.25721, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 9/120
# 50/50 [==============================] - 34s 686ms/step - loss: 3.3363 - accuracy: 0.1459 - top_5_accuracy: 0.4214 - val_loss: 3.1174 - val_accuracy: 0.2812 - val_top_5_accuracy: 0.5769
#
# Epoch 00009: val_accuracy improved from 0.25721 to 0.28125, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 10/120
# 50/50 [==============================] - 26s 513ms/step - loss: 3.1729 - accuracy: 0.1847 - top_5_accuracy: 0.4874 - val_loss: 2.8824 - val_accuracy: 0.3630 - val_top_5_accuracy: 0.6707
#
# Epoch 00010: val_accuracy improved from 0.28125 to 0.36298, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 11/120
# 50/50 [==============================] - 20s 409ms/step - loss: 2.9851 - accuracy: 0.2238 - top_5_accuracy: 0.5359 - val_loss: 2.7650 - val_accuracy: 0.3486 - val_top_5_accuracy: 0.6899
#
# Epoch 00011: val_accuracy did not improve from 0.36298
# Epoch 12/120
# 50/50 [==============================] - 18s 364ms/step - loss: 2.8576 - accuracy: 0.2575 - top_5_accuracy: 0.5701 - val_loss: 2.4803 - val_accuracy: 0.3726 - val_top_5_accuracy: 0.7620
#
# Epoch 00012: val_accuracy improved from 0.36298 to 0.37260, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 13/120
# 50/50 [==============================] - 15s 307ms/step - loss: 2.6274 - accuracy: 0.3025 - top_5_accuracy: 0.6377 - val_loss: 2.2960 - val_accuracy: 0.4207 - val_top_5_accuracy: 0.7668
#
# Epoch 00013: val_accuracy improved from 0.37260 to 0.42067, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 14/120
# 50/50 [==============================] - 16s 320ms/step - loss: 2.3971 - accuracy: 0.3606 - top_5_accuracy: 0.7064 - val_loss: 2.1677 - val_accuracy: 0.4639 - val_top_5_accuracy: 0.8101
#
# Epoch 00014: val_accuracy improved from 0.42067 to 0.46394, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 15/120
# 50/50 [==============================] - 16s 296ms/step - loss: 2.3723 - accuracy: 0.3721 - top_5_accuracy: 0.7037 - val_loss: 1.8900 - val_accuracy: 0.5072 - val_top_5_accuracy: 0.8125
#
# Epoch 00015: val_accuracy improved from 0.46394 to 0.50721, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 16/120
# 50/50 [==============================] - 13s 265ms/step - loss: 2.1582 - accuracy: 0.3938 - top_5_accuracy: 0.7507 - val_loss: 1.8546 - val_accuracy: 0.5216 - val_top_5_accuracy: 0.8245
#
# Epoch 00016: val_accuracy improved from 0.50721 to 0.52163, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 17/120
# 50/50 [==============================] - 14s 279ms/step - loss: 2.0213 - accuracy: 0.4455 - top_5_accuracy: 0.7761 - val_loss: 1.7600 - val_accuracy: 0.5457 - val_top_5_accuracy: 0.8726
#
# Epoch 00017: val_accuracy improved from 0.52163 to 0.54567, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 18/120
# 50/50 [==============================] - 14s 285ms/step - loss: 1.8703 - accuracy: 0.4797 - top_5_accuracy: 0.8293 - val_loss: 1.7776 - val_accuracy: 0.5433 - val_top_5_accuracy: 0.8389
#
# Epoch 00018: val_accuracy did not improve from 0.54567
# Epoch 19/120
# 50/50 [==============================] - 13s 263ms/step - loss: 1.8485 - accuracy: 0.4958 - top_5_accuracy: 0.8069 - val_loss: 1.5688 - val_accuracy: 0.5938 - val_top_5_accuracy: 0.8606
#
# Epoch 00019: val_accuracy improved from 0.54567 to 0.59375, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 20/120
# 50/50 [==============================] - 14s 273ms/step - loss: 1.6898 - accuracy: 0.5331 - top_5_accuracy: 0.8389 - val_loss: 1.5190 - val_accuracy: 0.6178 - val_top_5_accuracy: 0.8894
#
# Epoch 00020: val_accuracy improved from 0.59375 to 0.61779, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 21/120
# 50/50 [==============================] - 13s 266ms/step - loss: 1.5257 - accuracy: 0.5780 - top_5_accuracy: 0.8796 - val_loss: 1.4524 - val_accuracy: 0.6058 - val_top_5_accuracy: 0.8966
#
# Epoch 00021: val_accuracy did not improve from 0.61779
# Epoch 22/120
# 50/50 [==============================] - 13s 256ms/step - loss: 1.5156 - accuracy: 0.5653 - top_5_accuracy: 0.8808 - val_loss: 1.4868 - val_accuracy: 0.5913 - val_top_5_accuracy: 0.8942
#
# Epoch 00022: val_accuracy did not improve from 0.61779
# Epoch 23/120
# 50/50 [==============================] - 13s 256ms/step - loss: 1.3572 - accuracy: 0.6181 - top_5_accuracy: 0.8969 - val_loss: 1.5183 - val_accuracy: 0.6082 - val_top_5_accuracy: 0.8822
#
# Epoch 00023: val_accuracy did not improve from 0.61779
# Epoch 24/120
# 50/50 [==============================] - 13s 256ms/step - loss: 1.3080 - accuracy: 0.6259 - top_5_accuracy: 0.9002 - val_loss: 1.3373 - val_accuracy: 0.6322 - val_top_5_accuracy: 0.9087
#
# Epoch 00024: val_accuracy improved from 0.61779 to 0.63221, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 25/120
# 50/50 [==============================] - 13s 262ms/step - loss: 1.2291 - accuracy: 0.6682 - top_5_accuracy: 0.9220 - val_loss: 1.2735 - val_accuracy: 0.6322 - val_top_5_accuracy: 0.9062
#
# Epoch 00025: val_accuracy did not improve from 0.63221
# Epoch 26/120
# 50/50 [==============================] - 13s 258ms/step - loss: 1.1943 - accuracy: 0.6559 - top_5_accuracy: 0.9159 - val_loss: 1.3901 - val_accuracy: 0.6298 - val_top_5_accuracy: 0.8750
#
# Epoch 00026: val_accuracy did not improve from 0.63221
# Epoch 27/120
# 50/50 [==============================] - 13s 257ms/step - loss: 1.0585 - accuracy: 0.6942 - top_5_accuracy: 0.9429 - val_loss: 1.2299 - val_accuracy: 0.6803 - val_top_5_accuracy: 0.9159
#
# Epoch 00027: val_accuracy improved from 0.63221 to 0.68029, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 28/120
# 50/50 [==============================] - 13s 263ms/step - loss: 1.0594 - accuracy: 0.6889 - top_5_accuracy: 0.9223 - val_loss: 1.1539 - val_accuracy: 0.7019 - val_top_5_accuracy: 0.9014
#
# Epoch 00028: val_accuracy improved from 0.68029 to 0.70192, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 29/120
# 50/50 [==============================] - 13s 264ms/step - loss: 0.9778 - accuracy: 0.7115 - top_5_accuracy: 0.9347 - val_loss: 1.1257 - val_accuracy: 0.7019 - val_top_5_accuracy: 0.9159
#
# Epoch 00029: val_accuracy did not improve from 0.70192
# Epoch 30/120
# 50/50 [==============================] - 13s 259ms/step - loss: 0.8712 - accuracy: 0.7423 - top_5_accuracy: 0.9529 - val_loss: 1.1192 - val_accuracy: 0.6827 - val_top_5_accuracy: 0.9399
#
# Epoch 00030: val_accuracy did not improve from 0.70192
# Epoch 31/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.8982 - accuracy: 0.7228 - top_5_accuracy: 0.9602 - val_loss: 1.2075 - val_accuracy: 0.6587 - val_top_5_accuracy: 0.9087
#
# Epoch 00031: val_accuracy did not improve from 0.70192
# Epoch 32/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.8252 - accuracy: 0.7569 - top_5_accuracy: 0.9541 - val_loss: 1.0195 - val_accuracy: 0.7043 - val_top_5_accuracy: 0.9303
#
# Epoch 00032: val_accuracy improved from 0.70192 to 0.70433, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 33/120
# 50/50 [==============================] - 13s 262ms/step - loss: 0.6954 - accuracy: 0.8091 - top_5_accuracy: 0.9611 - val_loss: 1.0309 - val_accuracy: 0.7067 - val_top_5_accuracy: 0.9038
#
# Epoch 00033: val_accuracy improved from 0.70433 to 0.70673, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 34/120
# 50/50 [==============================] - 13s 263ms/step - loss: 0.7428 - accuracy: 0.7841 - top_5_accuracy: 0.9577 - val_loss: 1.1341 - val_accuracy: 0.6971 - val_top_5_accuracy: 0.9159
#
# Epoch 00034: val_accuracy did not improve from 0.70673
# Epoch 35/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.6692 - accuracy: 0.8111 - top_5_accuracy: 0.9673 - val_loss: 1.0591 - val_accuracy: 0.6995 - val_top_5_accuracy: 0.9062
#
# Epoch 00035: val_accuracy did not improve from 0.70673
# Epoch 36/120
# 50/50 [==============================] - 13s 260ms/step - loss: 0.6634 - accuracy: 0.8076 - top_5_accuracy: 0.9688 - val_loss: 1.1217 - val_accuracy: 0.6971 - val_top_5_accuracy: 0.9111
#
# Epoch 00036: val_accuracy did not improve from 0.70673
# Epoch 37/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.6512 - accuracy: 0.8007 - top_5_accuracy: 0.9764 - val_loss: 1.0322 - val_accuracy: 0.6971 - val_top_5_accuracy: 0.9255
#
# Epoch 00037: val_accuracy did not improve from 0.70673
# Epoch 38/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.5672 - accuracy: 0.8356 - top_5_accuracy: 0.9750 - val_loss: 1.0742 - val_accuracy: 0.7019 - val_top_5_accuracy: 0.9399
#
# Epoch 00038: val_accuracy did not improve from 0.70673
# Epoch 39/120
# 50/50 [==============================] - 13s 259ms/step - loss: 0.6039 - accuracy: 0.8192 - top_5_accuracy: 0.9716 - val_loss: 1.1246 - val_accuracy: 0.6971 - val_top_5_accuracy: 0.8990
#
# Epoch 00039: val_accuracy did not improve from 0.70673
# Epoch 40/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.5518 - accuracy: 0.8524 - top_5_accuracy: 0.9785 - val_loss: 0.9214 - val_accuracy: 0.7236 - val_top_5_accuracy: 0.9567
#
# Epoch 00040: val_accuracy improved from 0.70673 to 0.72356, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 41/120
# 50/50 [==============================] - 13s 263ms/step - loss: 0.5657 - accuracy: 0.8271 - top_5_accuracy: 0.9830 - val_loss: 0.9296 - val_accuracy: 0.7476 - val_top_5_accuracy: 0.9399
#
# Epoch 00041: val_accuracy improved from 0.72356 to 0.74760, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 42/120
# 50/50 [==============================] - 13s 262ms/step - loss: 0.5697 - accuracy: 0.8312 - top_5_accuracy: 0.9720 - val_loss: 1.1282 - val_accuracy: 0.6707 - val_top_5_accuracy: 0.9327
#
# Epoch 00042: val_accuracy did not improve from 0.74760
# Epoch 43/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.5695 - accuracy: 0.8222 - top_5_accuracy: 0.9772 - val_loss: 0.9469 - val_accuracy: 0.7428 - val_top_5_accuracy: 0.9519
#
# Epoch 00043: val_accuracy did not improve from 0.74760
# Epoch 44/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.4429 - accuracy: 0.8709 - top_5_accuracy: 0.9779 - val_loss: 0.9797 - val_accuracy: 0.6995 - val_top_5_accuracy: 0.9423
#
# Epoch 00044: val_accuracy did not improve from 0.74760
# Epoch 45/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.4564 - accuracy: 0.8650 - top_5_accuracy: 0.9904 - val_loss: 1.0538 - val_accuracy: 0.7188 - val_top_5_accuracy: 0.9279
#
# Epoch 00045: val_accuracy did not improve from 0.74760
# Epoch 46/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.4257 - accuracy: 0.8746 - top_5_accuracy: 0.9902 - val_loss: 1.0471 - val_accuracy: 0.7163 - val_top_5_accuracy: 0.9399
#
# Epoch 00046: val_accuracy did not improve from 0.74760
# Epoch 47/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.4360 - accuracy: 0.8581 - top_5_accuracy: 0.9890 - val_loss: 0.9825 - val_accuracy: 0.7284 - val_top_5_accuracy: 0.9279
#
# Epoch 00047: val_accuracy did not improve from 0.74760
# Epoch 48/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.3944 - accuracy: 0.8953 - top_5_accuracy: 0.9874 - val_loss: 1.0182 - val_accuracy: 0.7163 - val_top_5_accuracy: 0.9255
#
# Epoch 00048: val_accuracy did not improve from 0.74760
# Epoch 49/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.3555 - accuracy: 0.9017 - top_5_accuracy: 0.9931 - val_loss: 1.1334 - val_accuracy: 0.6827 - val_top_5_accuracy: 0.9135
#
# Epoch 00049: val_accuracy did not improve from 0.74760
# Epoch 50/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.3606 - accuracy: 0.8967 - top_5_accuracy: 0.9916 - val_loss: 1.0324 - val_accuracy: 0.7452 - val_top_5_accuracy: 0.9303
#
# Epoch 00050: val_accuracy did not improve from 0.74760
# Epoch 51/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.3374 - accuracy: 0.9013 - top_5_accuracy: 0.9926 - val_loss: 1.0207 - val_accuracy: 0.7356 - val_top_5_accuracy: 0.9231
#
# Epoch 00051: val_accuracy did not improve from 0.74760
# Epoch 52/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.3118 - accuracy: 0.9007 - top_5_accuracy: 0.9939 - val_loss: 1.0441 - val_accuracy: 0.7356 - val_top_5_accuracy: 0.9351
#
# Epoch 00052: val_accuracy did not improve from 0.74760
# Epoch 53/120
# 50/50 [==============================] - 13s 260ms/step - loss: 0.3509 - accuracy: 0.8995 - top_5_accuracy: 0.9944 - val_loss: 0.9050 - val_accuracy: 0.7548 - val_top_5_accuracy: 0.9495
#
# Epoch 00053: val_accuracy improved from 0.74760 to 0.75481, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 54/120
# 50/50 [==============================] - 13s 263ms/step - loss: 0.3035 - accuracy: 0.9224 - top_5_accuracy: 0.9953 - val_loss: 1.0917 - val_accuracy: 0.7188 - val_top_5_accuracy: 0.9207
#
# Epoch 00054: val_accuracy did not improve from 0.75481
# Epoch 55/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.3254 - accuracy: 0.9087 - top_5_accuracy: 0.9888 - val_loss: 1.0323 - val_accuracy: 0.7356 - val_top_5_accuracy: 0.9351
#
# Epoch 00055: val_accuracy did not improve from 0.75481
# Epoch 56/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.2535 - accuracy: 0.9342 - top_5_accuracy: 0.9946 - val_loss: 0.8997 - val_accuracy: 0.7668 - val_top_5_accuracy: 0.9495
#
# Epoch 00056: val_accuracy improved from 0.75481 to 0.76683, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 57/120
# 50/50 [==============================] - 13s 264ms/step - loss: 0.2657 - accuracy: 0.9199 - top_5_accuracy: 0.9949 - val_loss: 0.8136 - val_accuracy: 0.7861 - val_top_5_accuracy: 0.9495
#
# Epoch 00057: val_accuracy improved from 0.76683 to 0.78606, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 58/120
# 50/50 [==============================] - 13s 263ms/step - loss: 0.2519 - accuracy: 0.9213 - top_5_accuracy: 0.9943 - val_loss: 0.8982 - val_accuracy: 0.7596 - val_top_5_accuracy: 0.9591
#
# Epoch 00058: val_accuracy did not improve from 0.78606
# Epoch 59/120
# 50/50 [==============================] - 13s 259ms/step - loss: 0.2844 - accuracy: 0.9141 - top_5_accuracy: 0.9963 - val_loss: 1.0392 - val_accuracy: 0.7548 - val_top_5_accuracy: 0.9327
#
# Epoch 00059: val_accuracy did not improve from 0.78606
# Epoch 60/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.2738 - accuracy: 0.9173 - top_5_accuracy: 0.9963 - val_loss: 0.9940 - val_accuracy: 0.7452 - val_top_5_accuracy: 0.9207
#
# Epoch 00060: val_accuracy did not improve from 0.78606
# Epoch 61/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.2410 - accuracy: 0.9331 - top_5_accuracy: 0.9972 - val_loss: 1.1363 - val_accuracy: 0.7308 - val_top_5_accuracy: 0.9135
#
# Epoch 00061: val_accuracy did not improve from 0.78606
# Epoch 62/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.2358 - accuracy: 0.9350 - top_5_accuracy: 0.9932 - val_loss: 0.9742 - val_accuracy: 0.7548 - val_top_5_accuracy: 0.9303
#
# Epoch 00062: val_accuracy did not improve from 0.78606
# Epoch 63/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.2062 - accuracy: 0.9367 - top_5_accuracy: 0.9979 - val_loss: 0.9942 - val_accuracy: 0.7476 - val_top_5_accuracy: 0.9399
#
# Epoch 00063: val_accuracy did not improve from 0.78606
# Epoch 64/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.2038 - accuracy: 0.9357 - top_5_accuracy: 0.9982 - val_loss: 0.8901 - val_accuracy: 0.7644 - val_top_5_accuracy: 0.9231
#
# Epoch 00064: val_accuracy did not improve from 0.78606
# Epoch 65/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.2164 - accuracy: 0.9371 - top_5_accuracy: 0.9989 - val_loss: 1.1889 - val_accuracy: 0.7115 - val_top_5_accuracy: 0.9159
#
# Epoch 00065: val_accuracy did not improve from 0.78606
# Epoch 66/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1959 - accuracy: 0.9340 - top_5_accuracy: 0.9979 - val_loss: 0.9912 - val_accuracy: 0.7668 - val_top_5_accuracy: 0.9447
#
# Epoch 00066: val_accuracy did not improve from 0.78606
# Epoch 67/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1897 - accuracy: 0.9458 - top_5_accuracy: 0.9967 - val_loss: 1.0058 - val_accuracy: 0.7668 - val_top_5_accuracy: 0.9255
#
# Epoch 00067: val_accuracy did not improve from 0.78606
# Epoch 68/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1989 - accuracy: 0.9478 - top_5_accuracy: 0.9987 - val_loss: 0.9523 - val_accuracy: 0.7548 - val_top_5_accuracy: 0.9351
#
# Epoch 00068: val_accuracy did not improve from 0.78606
# Epoch 69/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1551 - accuracy: 0.9636 - top_5_accuracy: 0.9954 - val_loss: 1.0941 - val_accuracy: 0.7332 - val_top_5_accuracy: 0.9303
#
# Epoch 00069: val_accuracy did not improve from 0.78606
# Epoch 70/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1994 - accuracy: 0.9439 - top_5_accuracy: 0.9984 - val_loss: 1.1501 - val_accuracy: 0.7308 - val_top_5_accuracy: 0.9255
#
# Epoch 00070: val_accuracy did not improve from 0.78606
# Epoch 71/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1687 - accuracy: 0.9477 - top_5_accuracy: 0.9959 - val_loss: 1.0629 - val_accuracy: 0.7356 - val_top_5_accuracy: 0.9279
#
# Epoch 00071: val_accuracy did not improve from 0.78606
# Epoch 72/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1816 - accuracy: 0.9462 - top_5_accuracy: 1.0000 - val_loss: 0.9891 - val_accuracy: 0.7428 - val_top_5_accuracy: 0.9423
#
# Epoch 00072: val_accuracy did not improve from 0.78606
# Epoch 73/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1710 - accuracy: 0.9501 - top_5_accuracy: 0.9987 - val_loss: 1.1375 - val_accuracy: 0.7188 - val_top_5_accuracy: 0.9279
#
# Epoch 00073: val_accuracy did not improve from 0.78606
# Epoch 74/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1949 - accuracy: 0.9347 - top_5_accuracy: 0.9993 - val_loss: 1.0676 - val_accuracy: 0.7163 - val_top_5_accuracy: 0.9255
#
# Epoch 00074: val_accuracy did not improve from 0.78606
# Epoch 75/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.1449 - accuracy: 0.9550 - top_5_accuracy: 0.9973 - val_loss: 1.1993 - val_accuracy: 0.6995 - val_top_5_accuracy: 0.9375
#
# Epoch 00075: val_accuracy did not improve from 0.78606
# Epoch 76/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.1379 - accuracy: 0.9560 - top_5_accuracy: 0.9996 - val_loss: 1.0332 - val_accuracy: 0.7572 - val_top_5_accuracy: 0.9207
#
# Epoch 00076: val_accuracy did not improve from 0.78606
# Epoch 77/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1526 - accuracy: 0.9559 - top_5_accuracy: 1.0000 - val_loss: 0.9143 - val_accuracy: 0.7788 - val_top_5_accuracy: 0.9375
#
# Epoch 00077: val_accuracy did not improve from 0.78606
# Epoch 78/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1422 - accuracy: 0.9609 - top_5_accuracy: 1.0000 - val_loss: 0.9800 - val_accuracy: 0.7428 - val_top_5_accuracy: 0.9351
#
# Epoch 00078: val_accuracy did not improve from 0.78606
# Epoch 79/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1307 - accuracy: 0.9656 - top_5_accuracy: 0.9996 - val_loss: 1.1430 - val_accuracy: 0.7260 - val_top_5_accuracy: 0.9111
#
# Epoch 00079: val_accuracy did not improve from 0.78606
# Epoch 80/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1100 - accuracy: 0.9737 - top_5_accuracy: 0.9986 - val_loss: 0.9871 - val_accuracy: 0.7404 - val_top_5_accuracy: 0.9447
#
# Epoch 00080: val_accuracy did not improve from 0.78606
# Epoch 81/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1325 - accuracy: 0.9584 - top_5_accuracy: 1.0000 - val_loss: 1.2732 - val_accuracy: 0.6875 - val_top_5_accuracy: 0.8894
#
# Epoch 00081: val_accuracy did not improve from 0.78606
# Epoch 82/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1656 - accuracy: 0.9532 - top_5_accuracy: 0.9993 - val_loss: 0.9674 - val_accuracy: 0.7500 - val_top_5_accuracy: 0.9471
#
# Epoch 00082: val_accuracy did not improve from 0.78606
# Epoch 83/120
# 50/50 [==============================] - 13s 259ms/step - loss: 0.1386 - accuracy: 0.9537 - top_5_accuracy: 1.0000 - val_loss: 1.0536 - val_accuracy: 0.7548 - val_top_5_accuracy: 0.9399
#
# Epoch 00083: val_accuracy did not improve from 0.78606
# Epoch 84/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1097 - accuracy: 0.9694 - top_5_accuracy: 1.0000 - val_loss: 0.9175 - val_accuracy: 0.7837 - val_top_5_accuracy: 0.9423
#
# Epoch 00084: val_accuracy did not improve from 0.78606
# Epoch 85/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.1107 - accuracy: 0.9660 - top_5_accuracy: 1.0000 - val_loss: 0.9662 - val_accuracy: 0.7548 - val_top_5_accuracy: 0.9447
#
# Epoch 00085: val_accuracy did not improve from 0.78606
# Epoch 86/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.1509 - accuracy: 0.9517 - top_5_accuracy: 0.9981 - val_loss: 1.0960 - val_accuracy: 0.7308 - val_top_5_accuracy: 0.9423
#
# Epoch 00086: val_accuracy did not improve from 0.78606
# Epoch 87/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1079 - accuracy: 0.9694 - top_5_accuracy: 0.9990 - val_loss: 1.0809 - val_accuracy: 0.7332 - val_top_5_accuracy: 0.9255
#
# Epoch 00087: val_accuracy did not improve from 0.78606
# Epoch 88/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1353 - accuracy: 0.9479 - top_5_accuracy: 0.9994 - val_loss: 1.0186 - val_accuracy: 0.7572 - val_top_5_accuracy: 0.9303
#
# Epoch 00088: val_accuracy did not improve from 0.78606
# Epoch 89/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.1255 - accuracy: 0.9635 - top_5_accuracy: 1.0000 - val_loss: 1.0757 - val_accuracy: 0.7620 - val_top_5_accuracy: 0.9207
#
# Epoch 00089: val_accuracy did not improve from 0.78606
# Epoch 90/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0967 - accuracy: 0.9709 - top_5_accuracy: 0.9998 - val_loss: 0.9973 - val_accuracy: 0.7692 - val_top_5_accuracy: 0.9423
#
# Epoch 00090: val_accuracy did not improve from 0.78606
# Epoch 91/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0891 - accuracy: 0.9744 - top_5_accuracy: 0.9999 - val_loss: 0.9639 - val_accuracy: 0.7596 - val_top_5_accuracy: 0.9519
#
# Epoch 00091: val_accuracy did not improve from 0.78606
# Epoch 92/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1157 - accuracy: 0.9649 - top_5_accuracy: 1.0000 - val_loss: 1.0322 - val_accuracy: 0.7500 - val_top_5_accuracy: 0.9399
#
# Epoch 00092: val_accuracy did not improve from 0.78606
# Epoch 93/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0921 - accuracy: 0.9726 - top_5_accuracy: 0.9999 - val_loss: 1.1125 - val_accuracy: 0.7356 - val_top_5_accuracy: 0.9279
#
# Epoch 00093: val_accuracy did not improve from 0.78606
# Epoch 94/120
# 50/50 [==============================] - 13s 259ms/step - loss: 0.0982 - accuracy: 0.9705 - top_5_accuracy: 1.0000 - val_loss: 1.1454 - val_accuracy: 0.7332 - val_top_5_accuracy: 0.9543
#
# Epoch 00094: val_accuracy did not improve from 0.78606
# Epoch 95/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.1130 - accuracy: 0.9594 - top_5_accuracy: 0.9993 - val_loss: 1.0656 - val_accuracy: 0.7572 - val_top_5_accuracy: 0.9615
#
# Epoch 00095: val_accuracy did not improve from 0.78606
# Epoch 96/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0908 - accuracy: 0.9722 - top_5_accuracy: 1.0000 - val_loss: 1.1394 - val_accuracy: 0.7500 - val_top_5_accuracy: 0.9255
#
# Epoch 00096: val_accuracy did not improve from 0.78606
# Epoch 97/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0902 - accuracy: 0.9800 - top_5_accuracy: 0.9994 - val_loss: 1.1556 - val_accuracy: 0.7500 - val_top_5_accuracy: 0.9447
#
# Epoch 00097: val_accuracy did not improve from 0.78606
# Epoch 98/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.1217 - accuracy: 0.9620 - top_5_accuracy: 0.9976 - val_loss: 1.1539 - val_accuracy: 0.7260 - val_top_5_accuracy: 0.9423
#
# Epoch 00098: val_accuracy did not improve from 0.78606
# Epoch 99/120
# 50/50 [==============================] - 13s 260ms/step - loss: 0.0763 - accuracy: 0.9818 - top_5_accuracy: 1.0000 - val_loss: 1.2038 - val_accuracy: 0.7236 - val_top_5_accuracy: 0.9351
#
# Epoch 00099: val_accuracy did not improve from 0.78606
# Epoch 100/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0583 - accuracy: 0.9875 - top_5_accuracy: 0.9999 - val_loss: 1.1300 - val_accuracy: 0.7692 - val_top_5_accuracy: 0.9519
#
# Epoch 00100: val_accuracy did not improve from 0.78606
# Epoch 101/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0839 - accuracy: 0.9704 - top_5_accuracy: 1.0000 - val_loss: 1.2004 - val_accuracy: 0.7404 - val_top_5_accuracy: 0.9255
#
# Epoch 00101: val_accuracy did not improve from 0.78606
# Epoch 102/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0803 - accuracy: 0.9778 - top_5_accuracy: 1.0000 - val_loss: 1.0748 - val_accuracy: 0.7284 - val_top_5_accuracy: 0.9279
#
# Epoch 00102: val_accuracy did not improve from 0.78606
# Epoch 103/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0803 - accuracy: 0.9813 - top_5_accuracy: 1.0000 - val_loss: 1.1463 - val_accuracy: 0.7620 - val_top_5_accuracy: 0.9303
#
# Epoch 00103: val_accuracy did not improve from 0.78606
# Epoch 104/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0898 - accuracy: 0.9767 - top_5_accuracy: 0.9972 - val_loss: 1.2225 - val_accuracy: 0.6995 - val_top_5_accuracy: 0.9351
#
# Epoch 00104: val_accuracy did not improve from 0.78606
# Epoch 105/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0923 - accuracy: 0.9702 - top_5_accuracy: 0.9990 - val_loss: 1.1032 - val_accuracy: 0.7380 - val_top_5_accuracy: 0.9543
#
# Epoch 00105: val_accuracy did not improve from 0.78606
# Epoch 106/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0854 - accuracy: 0.9760 - top_5_accuracy: 1.0000 - val_loss: 1.0948 - val_accuracy: 0.7476 - val_top_5_accuracy: 0.9327
#
# Epoch 00106: val_accuracy did not improve from 0.78606
# Epoch 107/120
# 50/50 [==============================] - 13s 261ms/step - loss: 0.0867 - accuracy: 0.9746 - top_5_accuracy: 1.0000 - val_loss: 1.1493 - val_accuracy: 0.7212 - val_top_5_accuracy: 0.9471
#
# Epoch 00107: val_accuracy did not improve from 0.78606
# Epoch 108/120
# 50/50 [==============================] - 13s 259ms/step - loss: 0.0850 - accuracy: 0.9723 - top_5_accuracy: 1.0000 - val_loss: 1.0098 - val_accuracy: 0.7837 - val_top_5_accuracy: 0.9399
#
# Epoch 00108: val_accuracy did not improve from 0.78606
# Epoch 109/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0886 - accuracy: 0.9833 - top_5_accuracy: 1.0000 - val_loss: 1.1554 - val_accuracy: 0.7284 - val_top_5_accuracy: 0.9351
#
# Epoch 00109: val_accuracy did not improve from 0.78606
# Epoch 110/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0570 - accuracy: 0.9805 - top_5_accuracy: 1.0000 - val_loss: 0.9430 - val_accuracy: 0.7909 - val_top_5_accuracy: 0.9495
#
# Epoch 00110: val_accuracy improved from 0.78606 to 0.79087, saving model to /gdrive/MyDrive/Irfan/ckpts/VGG19.best.hdf5
# Epoch 111/120
# 50/50 [==============================] - 13s 263ms/step - loss: 0.0638 - accuracy: 0.9838 - top_5_accuracy: 1.0000 - val_loss: 1.0843 - val_accuracy: 0.7428 - val_top_5_accuracy: 0.9375
#
# Epoch 00111: val_accuracy did not improve from 0.79087
# Epoch 112/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0632 - accuracy: 0.9868 - top_5_accuracy: 0.9997 - val_loss: 1.0098 - val_accuracy: 0.7764 - val_top_5_accuracy: 0.9471
#
# Epoch 00112: val_accuracy did not improve from 0.79087
# Epoch 113/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0576 - accuracy: 0.9887 - top_5_accuracy: 0.9992 - val_loss: 1.0941 - val_accuracy: 0.7572 - val_top_5_accuracy: 0.9471
#
# Epoch 00113: val_accuracy did not improve from 0.79087
# Epoch 114/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0742 - accuracy: 0.9758 - top_5_accuracy: 1.0000 - val_loss: 0.9079 - val_accuracy: 0.7740 - val_top_5_accuracy: 0.9639
#
# Epoch 00114: val_accuracy did not improve from 0.79087
# Epoch 115/120
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0725 - accuracy: 0.9836 - top_5_accuracy: 1.0000 - val_loss: 1.2988 - val_accuracy: 0.7356 - val_top_5_accuracy: 0.9159
#
# Epoch 00115: val_accuracy did not improve from 0.79087
# Epoch 116/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0784 - accuracy: 0.9763 - top_5_accuracy: 1.0000 - val_loss: 0.9883 - val_accuracy: 0.7740 - val_top_5_accuracy: 0.9351
#
# Epoch 00116: val_accuracy did not improve from 0.79087
# Epoch 117/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0698 - accuracy: 0.9772 - top_5_accuracy: 1.0000 - val_loss: 1.1060 - val_accuracy: 0.7452 - val_top_5_accuracy: 0.9423
#
# Epoch 00117: val_accuracy did not improve from 0.79087
# Epoch 118/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0580 - accuracy: 0.9852 - top_5_accuracy: 1.0000 - val_loss: 1.1191 - val_accuracy: 0.7596 - val_top_5_accuracy: 0.9399
#
# Epoch 00118: val_accuracy did not improve from 0.79087
# Epoch 119/120
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0589 - accuracy: 0.9829 - top_5_accuracy: 1.0000 - val_loss: 1.0654 - val_accuracy: 0.7500 - val_top_5_accuracy: 0.9399
#
# Epoch 00119: val_accuracy did not improve from 0.79087
# Epoch 120/120
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0630 - accuracy: 0.9801 - top_5_accuracy: 1.0000 - val_loss: 1.0658 - val_accuracy: 0.7668 - val_top_5_accuracy: 0.9447
#
# Epoch 00120: val_accuracy did not improve from 0.79087
# <tensorflow.python.keras.engine.functional.Functional object at 0x7ff5358a8630> train accuracy: 0.025, <tensorflow.python.keras.engine.functional.Functional object at 0x7ff5358a8630> test accuracy: 0.031
# >Saved /gdrive/MyDrive/Irfan/models/h5/VGG19.h5

# %% [markdown]
# ##Top K Prediction

# %%
def get_top_k_predictions(preds, label_map, k=5, print_flag=False):
    sorted_array = np.argsort(preds)[::-1]
    top_k = sorted_array[:k]
    label_map_flip = dict((v,k) for k,v in label_map.items())
    
    y_pred = []
    for label_index in top_k:
        if print_flag:
            print("{} ({})".format(label_map_flip[label_index], preds[label_index]))
        y_pred.append(label_map_flip[label_index])
        
    return y_pred

# %%
label_map = (training_generator.class_indices)
 
json = js.dumps(label_map)
f = open("cough_label_map.json","w")
f.write(json)
f.close()

img_path = root + '/melspectrograms/testing/vacuum_cleaner/1-19872-A-36.png'

img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)* 1./255

preds = model.predict(x)[0]

get_top_k_predictions(preds, label_map, k=3)
# Out:
# ['vacuum_cleaner', 'engine', 'chainsaw']

# %% [markdown]
# ##Confusion Matrix

# %%
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(24,24))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
import os
from sklearn.metrics import confusion_matrix

testing_dir = root + '/melspectrograms/testing/'

y_true = []
y_pred = []
for label in label_map.keys():
    file_list = os.listdir(testing_dir + label)
    for file_name in file_list:
        img_path = testing_dir + label + '/' + file_name
        
        img = image.load_img(img_path, target_size=(224, 224))
        
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)* 1./255
        
        preds = model.predict(x)[0]
        
        y_true.append(label)
        y_pred.append(get_top_k_predictions(preds, label_map, k=1)[0])
        
cm = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, sorted(label_map.keys()), normalize=True)
# Out:
# Normalized confusion matrix
