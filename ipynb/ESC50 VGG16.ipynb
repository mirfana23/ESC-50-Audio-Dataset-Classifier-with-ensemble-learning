# %% [markdown]
# ##Mount Google Drive

# %%
import os
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ##Set up root

# %%
# Specify the directory path
root = '/gdrive/MyDrive/Irfan/ESC-50-master'
# !ls '/gdrive/MyDrive/Irfan/ESC-50-master'
# Out:
# audio			     LICENSE	      requirements.txt
# DenseNet201.best.hdf5	     melspectrograms  ResNet152V2.best.hdf5
# esc50.gif		     meta	      tests
# InceptionResNetV2.best.hdf5  pytest.ini       VGG19.best.hdf5
# InceptionV3.best.hdf5	     README.md	      Xception.best.hdf5

# %% [markdown]
# ##Import Libraries

# %%
from keras.applications.vgg16 import VGG16, preprocess_input #CHANGE THIS TO DIFFERENT MODEL
from keras.preprocessing import image
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Input
from keras.applications.vgg16 import preprocess_input
from matplotlib import pyplot as plt
import numpy as np
import json as js

# %% [markdown]
# ##Set Parameter Values

# %%
batch_size = 32
epochs = 100

# dimensions of our images.
img_width, img_height = 224, 224

input_tensor = Input(shape=(224,224,3))

nb_training_samples = 1600
nb_validation_samples = 400# Set parameter values

# %% [markdown]
# ##Data Loader

# %%
# training generator configuration
training_data_dir = root + '/melspectrograms/training'

training_datagen = image.ImageDataGenerator(
    rescale=1./255)

training_generator = training_datagen.flow_from_directory(
    training_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)

# validation generator configuration
validation_data_dir = root + '/melspectrograms/testing/'

validation_datagen = image.ImageDataGenerator(
    rescale=1./255)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 1600 images belonging to 50 classes.
# Found 400 images belonging to 50 classes.

# %% [markdown]
# ##Base Model

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor) #CHANGE THIS TO THE NAME OF THE MODEL
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Top Model

# %%
# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(50, activation='softmax')) #CHANGE HERE FOR THE AMOUNT OF CLASS
top_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                12850
# =================================================================
# Total params: 6,435,634
# Trainable params: 6,435,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Base + Top

# %%
model = Model(inputs=base_model.input, outputs=top_model(base_model.output))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# sequential (Sequential)      (None, 50)                6435634
# =================================================================
# Total params: 21,150,322
# Trainable params: 21,150,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Training configuration

# %%
from keras import metrics, optimizers

num_layers_to_freeze = 15

def top_5_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=5)

for layer in model.layers[:num_layers_to_freeze]:
    layer.trainable = False

# optimizer=optimizers.SGD(lr=1e-4, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), 
                      loss='categorical_crossentropy', 
                      metrics=['accuracy', top_5_accuracy])

# serialize model to JSON
model_json = model.to_json()
model_filename = "vgg16_model_{}_frozen_layers.json".format(num_layers_to_freeze)
with open(model_filename, "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ##Training Pipeline

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard
from time import time

tensorboard = TensorBoard(log_dir="logs/layers_frozen_{}".format(num_layers_to_freeze))

# checkpoint
filepath= root + "/VGG16.best.hdf5" #CHANGE THIS TOO
best_model_checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [best_model_checkpoint, tensorboard]


history = model.fit(
    training_generator,
    steps_per_epoch=nb_training_samples/batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples/batch_size,
    callbacks=callbacks_list)

# evaluate the model
train_acc = history.history['accuracy']
test_acc = history.history['val_accuracy']
print('%s train accuracy: %.3f, %s test accuracy: %.3f' % (model, train_acc[0], model, test_acc[0]))

#plotting accuracy
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.title(str(model) + 'accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

#plotting loss
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.title(str(model) + 'loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

filename = '/gdrive/MyDrive/Irfan/models/VGG16.h5' #CHANGE THIS
model.save(filename)
print('>Saved %s' % filename)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 888s 18s/step - loss: 4.1322 - accuracy: 0.0226 - top_5_accuracy: 0.1153 - val_loss: 3.8586 - val_accuracy: 0.0500 - val_top_5_accuracy: 0.1800
#
# Epoch 00001: val_accuracy improved from -inf to 0.05000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 2/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.8492 - accuracy: 0.0440 - top_5_accuracy: 0.1906 - val_loss: 3.8218 - val_accuracy: 0.0425 - val_top_5_accuracy: 0.2025
#
# Epoch 00002: val_accuracy did not improve from 0.05000
# Epoch 3/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.8139 - accuracy: 0.0431 - top_5_accuracy: 0.2206 - val_loss: 3.7606 - val_accuracy: 0.0975 - val_top_5_accuracy: 0.3025
#
# Epoch 00003: val_accuracy improved from 0.05000 to 0.09750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 4/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.7502 - accuracy: 0.0602 - top_5_accuracy: 0.2386 - val_loss: 3.6943 - val_accuracy: 0.0950 - val_top_5_accuracy: 0.3075
#
# Epoch 00004: val_accuracy did not improve from 0.09750
# Epoch 5/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.6967 - accuracy: 0.0795 - top_5_accuracy: 0.2737 - val_loss: 3.6209 - val_accuracy: 0.1225 - val_top_5_accuracy: 0.3950
#
# Epoch 00005: val_accuracy improved from 0.09750 to 0.12250, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 6/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.5822 - accuracy: 0.1088 - top_5_accuracy: 0.3275 - val_loss: 3.5356 - val_accuracy: 0.1600 - val_top_5_accuracy: 0.4425
#
# Epoch 00006: val_accuracy improved from 0.12250 to 0.16000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 7/100
# 50/50 [==============================] - 21s 416ms/step - loss: 3.5268 - accuracy: 0.1017 - top_5_accuracy: 0.3580 - val_loss: 3.4368 - val_accuracy: 0.2025 - val_top_5_accuracy: 0.4500
#
# Epoch 00007: val_accuracy improved from 0.16000 to 0.20250, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 8/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.4591 - accuracy: 0.1243 - top_5_accuracy: 0.3764 - val_loss: 3.3198 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.4850
#
# Epoch 00008: val_accuracy did not improve from 0.20250
# Epoch 9/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.3326 - accuracy: 0.1411 - top_5_accuracy: 0.4213 - val_loss: 3.1994 - val_accuracy: 0.2525 - val_top_5_accuracy: 0.5675
#
# Epoch 00009: val_accuracy improved from 0.20250 to 0.25250, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 10/100
# 50/50 [==============================] - 21s 416ms/step - loss: 3.1707 - accuracy: 0.2120 - top_5_accuracy: 0.4854 - val_loss: 3.0639 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.6125
#
# Epoch 00010: val_accuracy improved from 0.25250 to 0.30000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 11/100
# 50/50 [==============================] - 21s 415ms/step - loss: 3.0820 - accuracy: 0.2110 - top_5_accuracy: 0.5113 - val_loss: 2.9108 - val_accuracy: 0.3500 - val_top_5_accuracy: 0.6800
#
# Epoch 00011: val_accuracy improved from 0.30000 to 0.35000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 12/100
# 50/50 [==============================] - 21s 416ms/step - loss: 2.9394 - accuracy: 0.2384 - top_5_accuracy: 0.5646 - val_loss: 2.7809 - val_accuracy: 0.3225 - val_top_5_accuracy: 0.6850
#
# Epoch 00012: val_accuracy did not improve from 0.35000
# Epoch 13/100
# 50/50 [==============================] - 21s 415ms/step - loss: 2.7627 - accuracy: 0.2782 - top_5_accuracy: 0.6103 - val_loss: 2.6437 - val_accuracy: 0.4175 - val_top_5_accuracy: 0.7525
#
# Epoch 00013: val_accuracy improved from 0.35000 to 0.41750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 14/100
# 50/50 [==============================] - 21s 417ms/step - loss: 2.7107 - accuracy: 0.2802 - top_5_accuracy: 0.6357 - val_loss: 2.5011 - val_accuracy: 0.4575 - val_top_5_accuracy: 0.7500
#
# Epoch 00014: val_accuracy improved from 0.41750 to 0.45750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 15/100
# 50/50 [==============================] - 21s 415ms/step - loss: 2.5751 - accuracy: 0.3194 - top_5_accuracy: 0.6667 - val_loss: 2.4076 - val_accuracy: 0.4150 - val_top_5_accuracy: 0.7550
#
# Epoch 00015: val_accuracy did not improve from 0.45750
# Epoch 16/100
# 50/50 [==============================] - 21s 415ms/step - loss: 2.4274 - accuracy: 0.3579 - top_5_accuracy: 0.7047 - val_loss: 2.2692 - val_accuracy: 0.4725 - val_top_5_accuracy: 0.7925
#
# Epoch 00016: val_accuracy improved from 0.45750 to 0.47250, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 17/100
# 50/50 [==============================] - 21s 416ms/step - loss: 2.2685 - accuracy: 0.4268 - top_5_accuracy: 0.7394 - val_loss: 2.1911 - val_accuracy: 0.4950 - val_top_5_accuracy: 0.8250
#
# Epoch 00017: val_accuracy improved from 0.47250 to 0.49500, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 18/100
# 50/50 [==============================] - 21s 415ms/step - loss: 2.1882 - accuracy: 0.4197 - top_5_accuracy: 0.7518 - val_loss: 2.0601 - val_accuracy: 0.5150 - val_top_5_accuracy: 0.8125
#
# Epoch 00018: val_accuracy improved from 0.49500 to 0.51500, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 19/100
# 50/50 [==============================] - 21s 415ms/step - loss: 2.0957 - accuracy: 0.4277 - top_5_accuracy: 0.7836 - val_loss: 1.9549 - val_accuracy: 0.5350 - val_top_5_accuracy: 0.8200
#
# Epoch 00019: val_accuracy improved from 0.51500 to 0.53500, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 20/100
# 50/50 [==============================] - 21s 417ms/step - loss: 1.9275 - accuracy: 0.4823 - top_5_accuracy: 0.8103 - val_loss: 1.9050 - val_accuracy: 0.5475 - val_top_5_accuracy: 0.8375
#
# Epoch 00020: val_accuracy improved from 0.53500 to 0.54750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 21/100
# 50/50 [==============================] - 21s 414ms/step - loss: 1.9052 - accuracy: 0.4723 - top_5_accuracy: 0.8117 - val_loss: 1.7732 - val_accuracy: 0.5675 - val_top_5_accuracy: 0.8700
#
# Epoch 00021: val_accuracy improved from 0.54750 to 0.56750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 22/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.8033 - accuracy: 0.5291 - top_5_accuracy: 0.8390 - val_loss: 1.6880 - val_accuracy: 0.5900 - val_top_5_accuracy: 0.8675
#
# Epoch 00022: val_accuracy improved from 0.56750 to 0.59000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 23/100
# 50/50 [==============================] - 21s 416ms/step - loss: 1.7104 - accuracy: 0.5524 - top_5_accuracy: 0.8433 - val_loss: 1.6512 - val_accuracy: 0.5975 - val_top_5_accuracy: 0.8825
#
# Epoch 00023: val_accuracy improved from 0.59000 to 0.59750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 24/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.6119 - accuracy: 0.5575 - top_5_accuracy: 0.8671 - val_loss: 1.5967 - val_accuracy: 0.6000 - val_top_5_accuracy: 0.8875
#
# Epoch 00024: val_accuracy improved from 0.59750 to 0.60000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 25/100
# 50/50 [==============================] - 21s 416ms/step - loss: 1.5603 - accuracy: 0.6017 - top_5_accuracy: 0.8752 - val_loss: 1.5117 - val_accuracy: 0.6100 - val_top_5_accuracy: 0.8950
#
# Epoch 00025: val_accuracy improved from 0.60000 to 0.61000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 26/100
# 50/50 [==============================] - 21s 416ms/step - loss: 1.4351 - accuracy: 0.6169 - top_5_accuracy: 0.8955 - val_loss: 1.4709 - val_accuracy: 0.6200 - val_top_5_accuracy: 0.8950
#
# Epoch 00026: val_accuracy improved from 0.61000 to 0.62000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 27/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.3601 - accuracy: 0.6233 - top_5_accuracy: 0.8974 - val_loss: 1.4614 - val_accuracy: 0.6175 - val_top_5_accuracy: 0.9075
#
# Epoch 00027: val_accuracy did not improve from 0.62000
# Epoch 28/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.3650 - accuracy: 0.6194 - top_5_accuracy: 0.9048 - val_loss: 1.4094 - val_accuracy: 0.6275 - val_top_5_accuracy: 0.9000
#
# Epoch 00028: val_accuracy improved from 0.62000 to 0.62750, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 29/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.2187 - accuracy: 0.6754 - top_5_accuracy: 0.9191 - val_loss: 1.3527 - val_accuracy: 0.6325 - val_top_5_accuracy: 0.9100
#
# Epoch 00029: val_accuracy improved from 0.62750 to 0.63250, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 30/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.1835 - accuracy: 0.6678 - top_5_accuracy: 0.9261 - val_loss: 1.3404 - val_accuracy: 0.6350 - val_top_5_accuracy: 0.9000
#
# Epoch 00030: val_accuracy improved from 0.63250 to 0.63500, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 31/100
# 50/50 [==============================] - 21s 416ms/step - loss: 1.1936 - accuracy: 0.6547 - top_5_accuracy: 0.9330 - val_loss: 1.2854 - val_accuracy: 0.6600 - val_top_5_accuracy: 0.9300
#
# Epoch 00031: val_accuracy improved from 0.63500 to 0.66000, saving model to /gdrive/MyDrive/Irfan/ESC-50-master/VGG16.best.hdf5
# Epoch 32/100
# 50/50 [==============================] - 21s 416ms/step - loss: 1.1033 - accuracy: 0.7010 - top_5_accuracy: 0.9253 - val_loss: 1.2615 - val_accuracy: 0.6450 - val_top_5_accuracy: 0.9050
#
# Epoch 00032: val_accuracy did not improve from 0.66000
# Epoch 33/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.0265 - accuracy: 0.7231 - top_5_accuracy: 0.9379 - val_loss: 1.2314 - val_accuracy: 0.6375 - val_top_5_accuracy: 0.9175
#
# Epoch 00033: val_accuracy did not improve from 0.66000
# Epoch 34/100
# 50/50 [==============================] - 21s 415ms/step - loss: 1.0602 - accuracy: 0.7031 - top_5_accuracy: 0.9325 - val_loss: 1.2113 - val_accuracy: 0.6475 - val_top_5_accuracy: 0.9200
#
# Epoch 00034: val_accuracy did not improve from 0.66000
# Epoch 35/100
# 50/50 [==============================] - 21s 415ms/step - loss: 0.9793 - accuracy: 0.7341 - top_5_accuracy: 0.9541 - val_loss: 1.1666 - val_accuracy: 0.6500 - val_top_5_accuracy: 0.9300
#
# Epoch 00035: val_accuracy did not improve from 0.66000
# Epoch 36/100
# 50/50 [==============================] - 21s 416ms/step - loss: 0.9359 - accuracy: 0.7431 - top_5_accuracy: 0.9548 - val_loss: 1.1749 - val_accuracy: 0.6525 - val_top_5_accuracy: 0.9225
#
# Epoch 00036: val_accuracy did not improve from 0.66000
# Epoch 37/100
# 50/50 [==============================] - 21s 415ms/step - loss: 0.8932 - accuracy: 0.7618 - top_5_accuracy: 0.9607 - val_loss: 1.1665 - val_accuracy: 0.6600 - val_top_5_accuracy: 0.9325
#
# Epoch 00037: val_accuracy did not improve from 0.66000
# Epoch 38/100
# 50/50 [==============================] - 21s 415ms/step - loss: 0.8581 - accuracy: 0.7541 - top_5_accuracy: 0.9576 - val_loss: 1.1458 - val_accuracy: 0.6425 - val_top_5_accuracy: 0.9225
#
# Epoch 00038: val_accuracy did not improve from 0.66000
# Epoch 39/100
# 25/50 [==============>...............] - ETA: 8s - loss: 0.8833 - accuracy: 0.7502 - top_5_accuracy: 0.9541

# %% [markdown]
# ##Top K Prediction

# %%
def get_top_k_predictions(preds, label_map, k=5, print_flag=False):
    sorted_array = np.argsort(preds)[::-1]
    top_k = sorted_array[:k]
    label_map_flip = dict((v,k) for k,v in label_map.items())
    
    y_pred = []
    for label_index in top_k:
        if print_flag:
            print("{} ({})".format(label_map_flip[label_index], preds[label_index]))
        y_pred.append(label_map_flip[label_index])
        
    return y_pred

# %%
label_map = (training_generator.class_indices)
 
json = js.dumps(label_map)
f = open("cough_label_map.json","w")
f.write(json)
f.close()

img_path = root + '/melspectrograms/testing/vacuum_cleaner/1-19872-A-36.png'

img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)* 1./255

preds = model.predict(x)[0]

get_top_k_predictions(preds, label_map, k=3)

# %% [markdown]
# ##Confusion Matrix

# %%
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(24,24))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
import os
from sklearn.metrics import confusion_matrix

testing_dir = root + '/melspectrograms/testing/'

y_true = []
y_pred = []
for label in label_map.keys():
    file_list = os.listdir(testing_dir + label)
    for file_name in file_list:
        img_path = testing_dir + label + '/' + file_name
        
        img = image.load_img(img_path, target_size=(224, 224))
        
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)* 1./255
        
        preds = model.predict(x)[0]
        
        y_true.append(label)
        y_pred.append(get_top_k_predictions(preds, label_map, k=1)[0])
        
cm = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, sorted(label_map.keys()), normalize=True)
